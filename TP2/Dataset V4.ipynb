# %%
# %matplotlib inline

from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('dataset_v1').set_index('building_id')
df2 = pd.read_csv('dataset_v2').drop(columns=['Unnamed: 0']).set_index('building_id')
df3 = pd.read_csv('dataset_v3').set_index('building_id')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260601 entries, 802906 to 747594
# Data columns (total 54 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   geo_level_1_id                          260601 non-null  int64
#  1   geo_level_2_id                          260601 non-null  int64
#  2   geo_level_3_id                          260601 non-null  int64
#  3   count_floors_pre_eq                     260601 non-null  int64
#  4   age                                     260601 non-null  int64
#  5   area_percentage                         260601 non-null  int64
#  6   height_percentage                       260601 non-null  int64
#  7   has_superstructure_adobe_mud            260601 non-null  bool
#  8   has_superstructure_mud_mortar_stone     260601 non-null  bool
#  9   has_superstructure_stone_flag           260601 non-null  bool
#  10  has_superstructure_cement_mortar_stone  260601 non-null  bool
#  11  has_superstructure_mud_mortar_brick     260601 non-null  bool
#  12  has_superstructure_cement_mortar_brick  260601 non-null  bool
#  13  has_superstructure_timber               260601 non-null  bool
#  14  has_superstructure_bamboo               260601 non-null  bool
#  15  has_superstructure_rc_non_engineered    260601 non-null  bool
#  16  has_superstructure_rc_engineered        260601 non-null  bool
#  17  has_superstructure_other                260601 non-null  bool
#  18  count_families                          260601 non-null  int64
#  19  has_secondary_use                       260601 non-null  bool
#  20  has_secondary_use_agriculture           260601 non-null  bool
#  21  has_secondary_use_hotel                 260601 non-null  bool
#  22  has_secondary_use_rental                260601 non-null  bool
#  23  has_secondary_use_institution           260601 non-null  bool
#  24  has_secondary_use_school                260601 non-null  bool
#  25  has_secondary_use_industry              260601 non-null  bool
#  26  has_secondary_use_health_post           260601 non-null  bool
#  27  has_secondary_use_gov_office            260601 non-null  bool
#  28  has_secondary_use_use_police            260601 non-null  bool
#  29  has_secondary_use_other                 260601 non-null  bool
#  30  damage_grade                            260601 non-null  int64
#  31  roof_type_C1                            260601 non-null  int64
#  32  roof_type_C0                            260601 non-null  int64
#  33  land_surface_condition_C0               260601 non-null  int64
#  34  land_surface_condition_C1               260601 non-null  int64
#  35  foundation_type_C0                      260601 non-null  int64
#  36  foundation_type_C1                      260601 non-null  int64
#  37  foundation_type_C2                      260601 non-null  int64
#  38  ground_floor_type_C0                    260601 non-null  int64
#  39  ground_floor_type_C1                    260601 non-null  int64
#  40  ground_floor_type_C2                    260601 non-null  int64
#  41  other_floor_type_C0                     260601 non-null  int64
#  42  other_floor_type_C1                     260601 non-null  int64
#  43  other_floor_type_C2                     260601 non-null  int64
#  44  position_C0                             260601 non-null  int64
#  45  position_C1                             260601 non-null  int64
#  46  position_C2                             260601 non-null  int64
#  47  plan_configuration_C0                   260601 non-null  int64
#  48  plan_configuration_C1                   260601 non-null  int64
#  49  plan_configuration_C2                   260601 non-null  int64
#  50  plan_configuration_C3                   260601 non-null  int64
#  51  legal_ownership_status_C0               260601 non-null  int64
#  52  legal_ownership_status_C1               260601 non-null  int64
#  53  legal_ownership_status_C2               260601 non-null  int64
# dtypes: bool(22), int64(32)
# memory usage: 71.1 MB

# %%
# En esta version del dataset incluyo las siguientes columnas del df1,
# mas las columnas encodeadas del df2 (binary encoding).
# Descarto las columnas con informacion legal (usos secundarios y legal_status encodeado)
# NO incluyo damage_grade (esta en el csv 'train_labels.csv')

selected_features = [
    'geo_level_1_id',
    'geo_level_2_id',
    'geo_level_3_id',
    'age',
    'area_percentage',
    'height_percentage',
    'has_superstructure_adobe_mud',
    'has_superstructure_mud_mortar_stone',
    'has_superstructure_stone_flag',
    'has_superstructure_cement_mortar_stone',
    'has_superstructure_mud_mortar_brick',
    'has_superstructure_cement_mortar_brick',
    'has_superstructure_timber',
    'has_superstructure_bamboo',
    'has_superstructure_rc_non_engineered',
    'has_superstructure_rc_engineered'
]

df2_selected_features = [
    'roof_type_C0',
    'roof_type_C1',
    'land_surface_condition_C0',
    'land_surface_condition_C1',
    'foundation_type_C0',
    'foundation_type_C1',
    'foundation_type_C2',
    'ground_floor_type_C0',
    'ground_floor_type_C1',
    'ground_floor_type_C2',
    'other_floor_type_C0',
    'other_floor_type_C1',
    'other_floor_type_C2',
    'position_C0',
    'position_C1',
    'position_C2',
    'plan_configuration_C0',
    'plan_configuration_C1',
    'plan_configuration_C2',
    'plan_configuration_C3'
]

# %%
df2_subset = df2.loc[: , df2_selected_features]
df4 = df1.join(df2_subset).loc[:, selected_features + df2_selected_features]
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260601 entries, 802906 to 747594
# Data columns (total 36 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   geo_level_1_id                          260601 non-null  int64
#  1   geo_level_2_id                          260601 non-null  int64
#  2   geo_level_3_id                          260601 non-null  int64
#  3   age                                     260601 non-null  int64
#  4   area_percentage                         260601 non-null  int64
#  5   height_percentage                       260601 non-null  int64
#  6   has_superstructure_adobe_mud            260601 non-null  bool
#  7   has_superstructure_mud_mortar_stone     260601 non-null  bool
#  8   has_superstructure_stone_flag           260601 non-null  bool
#  9   has_superstructure_cement_mortar_stone  260601 non-null  bool
#  10  has_superstructure_mud_mortar_brick     260601 non-null  bool
#  11  has_superstructure_cement_mortar_brick  260601 non-null  bool
#  12  has_superstructure_timber               260601 non-null  bool
#  13  has_superstructure_bamboo               260601 non-null  bool
#  14  has_superstructure_rc_non_engineered    260601 non-null  bool
#  15  has_superstructure_rc_engineered        260601 non-null  bool
#  16  roof_type_C0                            260601 non-null  int64
#  17  roof_type_C1                            260601 non-null  int64
#  18  land_surface_condition_C0               260601 non-null  int64
#  19  land_surface_condition_C1               260601 non-null  int64
#  20  foundation_type_C0                      260601 non-null  int64
#  21  foundation_type_C1                      260601 non-null  int64
#  22  foundation_type_C2                      260601 non-null  int64
#  23  ground_floor_type_C0                    260601 non-null  int64
#  24  ground_floor_type_C1                    260601 non-null  int64
#  25  ground_floor_type_C2                    260601 non-null  int64
#  26  other_floor_type_C0                     260601 non-null  int64
#  27  other_floor_type_C1                     260601 non-null  int64
#  28  other_floor_type_C2                     260601 non-null  int64
#  29  position_C0                             260601 non-null  int64
#  30  position_C1                             260601 non-null  int64
#  31  position_C2                             260601 non-null  int64
#  32  plan_configuration_C0                   260601 non-null  int64
#  33  plan_configuration_C1                   260601 non-null  int64
#  34  plan_configuration_C2                   260601 non-null  int64
#  35  plan_configuration_C3                   260601 non-null  int64
# dtypes: bool(10), int64(26)
# memory usage: 66.2 MB

# %%
df4.to_csv('dataset_v4.csv')
