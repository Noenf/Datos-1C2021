# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default')

# %%
df = pd.read_csv('dataset_v1')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260601 entries, 0 to 260600
# Data columns (total 40 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  int64
#  2   geo_level_2_id                          260601 non-null  int64
#  3   geo_level_3_id                          260601 non-null  int64
#  4   count_floors_pre_eq                     260601 non-null  int64
#  5   age                                     260601 non-null  int64
#  6   area_percentage                         260601 non-null  int64
#  7   height_percentage                       260601 non-null  int64
#  8   land_surface_condition                  260601 non-null  object
#  9   foundation_type                         260601 non-null  object
#  10  roof_type                               260601 non-null  object
#  11  ground_floor_type                       260601 non-null  object
#  12  other_floor_type                        260601 non-null  object
#  13  position                                260601 non-null  object
#  14  plan_configuration                      260601 non-null  object
#  15  has_superstructure_adobe_mud            260601 non-null  bool
#  16  has_superstructure_mud_mortar_stone     260601 non-null  bool
#  17  has_superstructure_stone_flag           260601 non-null  bool
#  18  has_superstructure_cement_mortar_stone  260601 non-null  bool
#  19  has_superstructure_mud_mortar_brick     260601 non-null  bool
#  20  has_superstructure_cement_mortar_brick  260601 non-null  bool
#  21  has_superstructure_timber               260601 non-null  bool
#  22  has_superstructure_bamboo               260601 non-null  bool
#  23  has_superstructure_rc_non_engineered    260601 non-null  bool
#  24  has_superstructure_rc_engineered        260601 non-null  bool
#  25  has_superstructure_other                260601 non-null  bool
#  26  legal_ownership_status                  260601 non-null  object
#  27  count_families                          260601 non-null  int64
#  28  has_secondary_use                       260601 non-null  bool
#  29  has_secondary_use_agriculture           260601 non-null  bool
#  30  has_secondary_use_hotel                 260601 non-null  bool
#  31  has_secondary_use_rental                260601 non-null  bool
#  32  has_secondary_use_institution           260601 non-null  bool
#  33  has_secondary_use_school                260601 non-null  bool
#  34  has_secondary_use_industry              260601 non-null  bool
#  35  has_secondary_use_health_post           260601 non-null  bool
#  36  has_secondary_use_gov_office            260601 non-null  bool
#  37  has_secondary_use_use_police            260601 non-null  bool
#  38  has_secondary_use_other                 260601 non-null  bool
#  39  damage_grade                            260601 non-null  int64
# dtypes: bool(22), int64(10), object(8)
# memory usage: 43.2+ MB

# %% [markdown]
# # Structures (categoricos)

# %%
structures = df.loc[:, 'has_superstructure_adobe_mud' : 'has_superstructure_other']
struc = structures.head()
struc
# Out:
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# 0                          True                                 True
# 1                         False                                 True
# 2                         False                                 True
# 3                         False                                 True
# 4                          True                                False
#
#    has_superstructure_stone_flag  has_superstructure_cement_mortar_stone  \
# 0                          False                                   False
# 1                          False                                   False
# 2                          False                                   False
# 3                          False                                   False
# 4                          False                                   False
#
#    has_superstructure_mud_mortar_brick  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    has_superstructure_cement_mortar_brick  has_superstructure_timber  \
# 0                                   False                      False
# 1                                   False                      False
# 2                                   False                      False
# 3                                   False                       True
# 4                                   False                      False
#
#    has_superstructure_bamboo  has_superstructure_rc_non_engineered  \
# 0                      False                                 False
# 1                      False                                 False
# 2                      False                                 False
# 3                       True                                 False
# 4                      False                                 False
#
#    has_superstructure_rc_engineered  has_superstructure_other
# 0                             False                     False
# 1                             False                     False
# 2                             False                     False
# 3                             False                     False
# 4                             False                     False

# %%
s = df.loc[:, 'has_superstructure_adobe_mud' : 'has_superstructure_stone_flag'].head()
s

col_mean = s['has_superstructure_adobe_mud'].mean()
s.loc[s['has_superstructure_adobe_mud'], 'has_superstructure_adobe_mud_mean'] = col_mean
s.loc[~s['has_superstructure_adobe_mud'], 'has_superstructure_adobe_mud_mean'] = 1 - col_mean
s
# Out:
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# 0                          True                                 True
# 1                         False                                 True
# 2                         False                                 True
# 3                         False                                 True
# 4                          True                                False
#
#    has_superstructure_stone_flag  has_superstructure_adobe_mud_mean
# 0                          False                                0.4
# 1                          False                                0.6
# 2                          False                                0.6
# 3                          False                                0.6
# 4                          False                                0.4

# %%
cols = [
	'has_superstructure_adobe_mud',
	'has_superstructure_mud_mortar_stone',
	'has_superstructure_stone_flag',
	'has_superstructure_cement_mortar_stone',
	'has_superstructure_mud_mortar_brick',
	'has_superstructure_cement_mortar_brick',
	'has_superstructure_timber',
	'has_superstructure_bamboo',
	'has_superstructure_rc_non_engineered',
	'has_superstructure_rc_engineered',
	'has_superstructure_other'
]

for col_name in cols:
    col_mean = structures[col_name].mean()
    structures.loc[structures[col_name], col_name + '_mean'] = col_mean
    structures.loc[~structures[col_name], col_name + '_mean'] = 1 - col_mean
    
structures
# Out:
#         has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  \
# 0                               True                                 True
# 1                              False                                 True
# 2                              False                                 True
# 3                              False                                 True
# 4                               True                                False
# ...                              ...                                  ...
# 260596                         False                                 True
# 260597                         False                                 True
# 260598                         False                                 True
# 260599                         False                                False
# 260600                         False                                 True
#
#         has_superstructure_stone_flag  has_superstructure_cement_mortar_stone  \
# 0                               False                                   False
# 1                               False                                   False
# 2                               False                                   False
# 3                               False                                   False
# 4                               False                                   False
# ...                               ...                                     ...
# 260596                          False                                   False
# 260597                          False                                   False
# 260598                          False                                   False
# 260599                          False                                   False
# 260600                          False                                   False
#
#         has_superstructure_mud_mortar_brick  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 260596                                False
# 260597                                False
# 260598                                False
# 260599                                False
# 260600                                False
#
#         has_superstructure_cement_mortar_brick  has_superstructure_timber  \
# 0                                        False                      False
# 1                                        False                      False
# 2                                        False                      False
# 3                                        False                       True
# 4                                        False                      False
# ...                                        ...                        ...
# 260596                                   False                      False
# 260597                                   False                      False
# 260598                                   False                      False
# 260599                                    True                      False
# 260600                                   False                      False
#
#         has_superstructure_bamboo  has_superstructure_rc_non_engineered  \
# 0                           False                                 False
# 1                           False                                 False
# 2                           False                                 False
# 3                            True                                 False
# 4                           False                                 False
# ...                           ...                                   ...
# 260596                      False                                 False
# 260597                      False                                 False
# 260598                      False                                 False
# 260599                      False                                 False
# 260600                      False                                 False
#
#         has_superstructure_rc_engineered  ...  \
# 0                                  False  ...
# 1                                  False  ...
# 2                                  False  ...
# 3                                  False  ...
# 4                                  False  ...
# ...                                  ...  ...
# 260596                             False  ...
# 260597                             False  ...
# 260598                             False  ...
# 260599                             False  ...
# 260600                             False  ...
#
#         has_superstructure_mud_mortar_stone_mean  \
# 0                                       0.761935
# 1                                       0.761935
# 2                                       0.761935
# 3                                       0.761935
# 4                                       0.238065
# ...                                          ...
# 260596                                  0.761935
# 260597                                  0.761935
# 260598                                  0.761935
# 260599                                  0.238065
# 260600                                  0.761935
#
#         has_superstructure_stone_flag_mean  \
# 0                                 0.965668
# 1                                 0.965668
# 2                                 0.965668
# 3                                 0.965668
# 4                                 0.965668
# ...                                    ...
# 260596                            0.965668
# 260597                            0.965668
# 260598                            0.965668
# 260599                            0.965668
# 260600                            0.965668
#
#         has_superstructure_cement_mortar_stone_mean  \
# 0                                          0.981765
# 1                                          0.981765
# 2                                          0.981765
# 3                                          0.981765
# 4                                          0.981765
# ...                                             ...
# 260596                                     0.981765
# 260597                                     0.981765
# 260598                                     0.981765
# 260599                                     0.981765
# 260600                                     0.981765
#
#         has_superstructure_mud_mortar_brick_mean  \
# 0                                       0.931846
# 1                                       0.931846
# 2                                       0.931846
# 3                                       0.931846
# 4                                       0.931846
# ...                                          ...
# 260596                                  0.931846
# 260597                                  0.931846
# 260598                                  0.931846
# 260599                                  0.931846
# 260600                                  0.931846
#
#         has_superstructure_cement_mortar_brick_mean  \
# 0                                          0.924732
# 1                                          0.924732
# 2                                          0.924732
# 3                                          0.924732
# 4                                          0.924732
# ...                                             ...
# 260596                                     0.924732
# 260597                                     0.924732
# 260598                                     0.924732
# 260599                                     0.075268
# 260600                                     0.924732
#
#         has_superstructure_timber_mean  has_superstructure_bamboo_mean  \
# 0                             0.745012                        0.914989
# 1                             0.745012                        0.914989
# 2                             0.745012                        0.914989
# 3                             0.254988                        0.085011
# 4                             0.745012                        0.914989
# ...                                ...                             ...
# 260596                        0.745012                        0.914989
# 260597                        0.745012                        0.914989
# 260598                        0.745012                        0.914989
# 260599                        0.745012                        0.914989
# 260600                        0.745012                        0.914989
#
#         has_superstructure_rc_non_engineered_mean  \
# 0                                         0.95741
# 1                                         0.95741
# 2                                         0.95741
# 3                                         0.95741
# 4                                         0.95741
# ...                                           ...
# 260596                                    0.95741
# 260597                                    0.95741
# 260598                                    0.95741
# 260599                                    0.95741
# 260600                                    0.95741
#
#         has_superstructure_rc_engineered_mean  has_superstructure_other_mean
# 0                                    0.984141                       0.985015
# 1                                    0.984141                       0.985015
# 2                                    0.984141                       0.985015
# 3                                    0.984141                       0.985015
# 4                                    0.984141                       0.985015
# ...                                       ...                            ...
# 260596                               0.984141                       0.985015
# 260597                               0.984141                       0.985015
# 260598                               0.984141                       0.985015
# 260599                               0.984141                       0.985015
# 260600                               0.984141                       0.985015
#
# [260601 rows x 22 columns]

# %% [markdown]
# # Building categoricals

# %%
cc = [ # cc: "categorical columns"
	'land_surface_condition',
	'foundation_type',
	'roof_type',
	'ground_floor_type',
	'other_floor_type',
	'position',
	'plan_configuration',
    'legal_ownership_status'
]

build_cats = df.loc[:, cc]

# land_surface_condition
build_cats[cc[0]].replace(
    {"n": cc[0]+" N", "o":  cc[0]+" O", "t": cc[0]+" T"},
    inplace=True
)
# foundation_type
build_cats[cc[1]].replace(
    {"h": cc[1]+" H", "i":  cc[1]+" I", "r": cc[1]+" R", "u": cc[1]+" U", "w": cc[1]+" W"},
    inplace=True
)
# roof_type
build_cats[cc[2]].replace(
    {"n": cc[2]+" N", "q":  cc[2]+" Q", "x": cc[2]+" X"},
    inplace=True
)
# ground_floor_type
build_cats[cc[3]].replace(
    {"f": cc[3]+" F", "m":  cc[3]+" M", "v": cc[3]+" V", "x": cc[3]+" X", "z": cc[3]+" Z"},
    inplace=True
)
# other_floor_type
build_cats[cc[4]].replace(
    {"j": cc[4]+" J", "q":  cc[4]+" Q", "s": cc[4]+" S", "x": cc[4]+" X"},
    inplace=True
)
# position
build_cats[cc[5]].replace(
    {"j": cc[5]+" H", "o":  cc[5]+" O", "s": cc[5]+" S", "t": cc[5]+" T"},
    inplace=True
)
# plan_configuration
build_cats[cc[6]].replace(
    {"a": cc[6]+" A", "c": cc[6]+" C", "d": cc[6]+" D", "f": cc[6]+" F", "m": cc[6]+" M",
     "n": cc[6]+" N", "o": cc[6]+" O", "q": cc[6]+" Q", "s": cc[6]+" S", "u": cc[6]+" U"},
    inplace=True
)
# legal_ownership_status
build_cats[cc[7]].replace(
    {"a": cc[7]+" A", "r":  cc[7]+" R", "v": cc[7]+" V", "w": cc[7]+" W"},
    inplace=True
)

for col_name in cc:
    dummies = pd.get_dummies(build_cats[col_name])
    build_cats = pd.concat([build_cats, dummies], axis=1)
    
build_cats = build_cats.drop(columns=cc)
build_cats.loc[build_cats['foundation_type H'] == 1]
# Out:
#         land_surface_condition N  land_surface_condition O  \
# 34                             0                         0
# 178                            1                         0
# 398                            0                         0
# 462                            0                         0
# 549                            0                         0
# ...                          ...                       ...
# 259247                         0                         0
# 259280                         0                         0
# 259333                         1                         0
# 259827                         0                         0
# 260523                         0                         0
#
#         land_surface_condition T  foundation_type H  foundation_type I  \
# 34                             1                  1                  0
# 178                            0                  1                  0
# 398                            1                  1                  0
# 462                            1                  1                  0
# 549                            1                  1                  0
# ...                          ...                ...                ...
# 259247                         1                  1                  0
# 259280                         1                  1                  0
# 259333                         0                  1                  0
# 259827                         1                  1                  0
# 260523                         1                  1                  0
#
#         foundation_type R  foundation_type U  foundation_type W  roof_type N  \
# 34                      0                  0                  0            1
# 178                     0                  0                  0            1
# 398                     0                  0                  0            1
# 462                     0                  0                  0            1
# 549                     0                  0                  0            0
# ...                   ...                ...                ...          ...
# 259247                  0                  0                  0            1
# 259280                  0                  0                  0            0
# 259333                  0                  0                  0            1
# 259827                  0                  0                  0            0
# 260523                  0                  0                  0            0
#
#         roof_type Q  ...  plan_configuration M  plan_configuration N  \
# 34                0  ...                     0                     0
# 178               0  ...                     0                     0
# 398               0  ...                     0                     0
# 462               0  ...                     0                     0
# 549               1  ...                     0                     0
# ...             ...  ...                   ...                   ...
# 259247            0  ...                     0                     0
# 259280            1  ...                     0                     0
# 259333            0  ...                     0                     0
# 259827            1  ...                     0                     0
# 260523            1  ...                     0                     0
#
#         plan_configuration O  plan_configuration Q  plan_configuration S  \
# 34                         0                     0                     0
# 178                        0                     0                     0
# 398                        0                     0                     0
# 462                        0                     0                     0
# 549                        0                     0                     0
# ...                      ...                   ...                   ...
# 259247                     0                     0                     0
# 259280                     0                     0                     0
# 259333                     0                     0                     0
# 259827                     0                     0                     0
# 260523                     0                     0                     0
#
#         plan_configuration U  legal_ownership_status A  \
# 34                         0                         0
# 178                        0                         0
# 398                        0                         0
# 462                        0                         0
# 549                        0                         0
# ...                      ...                       ...
# 259247                     0                         0
# 259280                     0                         0
# 259333                     0                         0
# 259827                     0                         0
# 260523                     0                         1
#
#         legal_ownership_status R  legal_ownership_status V  \
# 34                             0                         1
# 178                            0                         1
# 398                            0                         1
# 462                            0                         1
# 549                            0                         1
# ...                          ...                       ...
# 259247                         0                         1
# 259280                         0                         1
# 259333                         0                         1
# 259827                         0                         1
# 260523                         0                         0
#
#         legal_ownership_status W
# 34                             0
# 178                            0
# 398                            0
# 462                            0
# 549                            0
# ...                          ...
# 259247                         0
# 259280                         0
# 259333                         0
# 259827                         0
# 260523                         0
#
# [1448 rows x 38 columns]

# %% [markdown]
# Problema principal de hacer one hot encoding de esta forma: practicamente se duplica la cantidad de columnas

# %% [markdown]
# # Numericos

# %%
nums = df.loc[:, ['area_percentage', 'height_percentage']]
nums.describe()
# Out:
#        area_percentage  height_percentage
# count    260601.000000      260601.000000
# mean          8.018051           5.434365
# std           4.392231           1.918418
# min           1.000000           2.000000
# 25%           5.000000           4.000000
# 50%           7.000000           5.000000
# 75%           9.000000           6.000000
# max         100.000000          32.000000

# %% [markdown]
# Podemos asumir que `area_percentage` es un porcentaje (el minimo es 1 y el maximo es 100), pero que pasa con `height_percentage`?
#
# De todas formas podemos normalizar ambos a un numero entre 0 y 1 con:
#
# ```
# norm(x) = (x - min) / (max - min)
# ```

# %%
from sklearn import preprocessing

values = nums.values
scaler = preprocessing.MinMaxScaler()
scaled_values = scaler.fit_transform(values)
scaled_nums = pd.DataFrame(scaled_values)
scaled_nums.rename(
    columns={0: 'area_percentage_norm', 1: 'height_percentage_norm'},
    inplace=True
)
scaled_nums.head()
# Out:
#    area_percentage_norm  height_percentage_norm
# 0              0.050505                0.100000
# 1              0.070707                0.166667
# 2              0.040404                0.100000
# 3              0.050505                0.100000
# 4              0.070707                0.233333

# %%
nums.head()
# Out:
#    area_percentage  height_percentage
# 0                6                  5
# 1                8                  7
# 2                5                  5
# 3                6                  5
# 4                8                  9
