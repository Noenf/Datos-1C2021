# %%
import datetime as datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('dataset_v1')
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_hotel  \
# 0                      t               r  ...                   False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260601 entries, 0 to 260600
# Data columns (total 40 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  int64
#  2   geo_level_2_id                          260601 non-null  int64
#  3   geo_level_3_id                          260601 non-null  int64
#  4   count_floors_pre_eq                     260601 non-null  int64
#  5   age                                     260601 non-null  int64
#  6   area_percentage                         260601 non-null  int64
#  7   height_percentage                       260601 non-null  int64
#  8   land_surface_condition                  260601 non-null  object
#  9   foundation_type                         260601 non-null  object
# ...

# %%
df['roof_type'].value_counts()
# Out:
# n    182842
# q     61576
# x     16183
# Name: roof_type, dtype: int64

# %%
df['roof_type_C1'] = 0
df['roof_type_C0'] = 0
df['roof_type_C1'] = df['roof_type_C1'].astype('int64') 
df['roof_type_C0'] = df['roof_type_C0'].astype('int64')
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_institution  \
# 0                      t               r  ...                         False
# ...

# %%
#land_surface_condition                  260601 non-null  object
#foundation_type                         260601 non-null  object
#roof_type                               260601 non-null  object
#ground_floor_type                       260601 non-null  object
#other_floor_type                        260601 non-null  object
#position                                260601 non-null  object
#plan_configuration                      260601 non-null  object
#legal_ownership_status                  260601 non-null  object

# %%
#roof_type 
# valor n= 01
# valor q= 10
# valor x= 11
def binarioRoofType_C0(valor):
    if ((valor == 'n') or (valor == 'x')):
        return 1;
    else: return 0;
    
def binarioRoofType_C1(valor):
    if ((valor == 'q') or (valor == 'x')):
        return 1;
    else: return 0;

# %%
df['roof_type_C1'] = df['roof_type'].apply(binarioRoofType_C1)
df['roof_type_C0'] = df['roof_type'].apply(binarioRoofType_C0)
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_institution  \
# 0                      t               r  ...                         False
# ...

# %%
df[['roof_type','roof_type_C1','roof_type_C0']]
# Out:
#        roof_type  roof_type_C1  roof_type_C0
# 0              n             0             1
# 1              n             0             1
# 2              n             0             1
# 3              n             0             1
# 4              n             0             1
# ...          ...           ...           ...
# 260596         n             0             1
# 260597         n             0             1
# 260598         q             1             0
# 260599         x             1             1
# 260600         n             0             1
#
# [260601 rows x 3 columns]

# %%
df['land_surface_condition'].value_counts()
# Out:
# t    216757
# n     35528
# o      8316
# Name: land_surface_condition, dtype: int64

# %%
#land_surface_condition 
# valor t= 01
# valor n= 10
# valor o= 11
def binario_land_surface_condition_C0(valor):
    if ((valor == 't') or (valor == 'o')):
        return 1;
    else: return 0;
    
def binario_land_surface_condition_C1(valor):
    if ((valor == 'n') or (valor == 'o')):
        return 1;
    else: return 0;

# %%
df['land_surface_condition_C0'] =0
df['land_surface_condition_C1'] =0

# %%
df['land_surface_condition_C1'] = df['land_surface_condition'].apply(binario_land_surface_condition_C1)
df['land_surface_condition_C0'] = df['land_surface_condition'].apply(binario_land_surface_condition_C0)
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_industry  \
# 0                      t               r  ...                      False
# ...

# %%
df['foundation_type'].value_counts()
# Out:
# r    219196
# w     15118
# u     14260
# i     10579
# h      1448
# Name: foundation_type, dtype: int64

# %%
#foundation_type 
# valor r= 001
# valor w= 010
# valor u= 011
# valor i= 100
# valor n= 101

def binario_foundation_type_C0(valor):
    if ((valor == 'r') or (valor == 'u') or (valor == 'n')):
        return 1;
    else: return 0;
    
def binario_foundation_type_C1(valor):
    if ((valor == 'w') or (valor == 'u')):
        return 1;
    else: return 0;

def binario_foundation_type_C2(valor):
    if ((valor == 'i') or (valor == 'n')):
        return 1;
    else: return 0;
    

df['foundation_type_C0'] =0
df['foundation_type_C1'] =0
df['foundation_type_C2'] =0

df['foundation_type_C0'] = df['foundation_type'].apply(binario_foundation_type_C0)
df['foundation_type_C1'] = df['foundation_type'].apply(binario_foundation_type_C1)
df['foundation_type_C2'] = df['foundation_type'].apply(binario_foundation_type_C2)
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... has_secondary_use_use_police  \
# 0                      t               r  ...                        False
# ...

# %%
df['ground_floor_type'].value_counts()
# Out:
# f    209619
# x     24877
# v     24593
# z      1004
# m       508
# Name: ground_floor_type, dtype: int64

# %%
#ground_floor_type
# valor f= 001
# valor x= 010
# valor v= 011
# valor z= 100
# valor m= 101

def binario_ground_floor_type_C0(valor):
    if ((valor == 'f') or (valor == 'v') or (valor == 'm')):
        return 1;
    else: return 0;
    
def binario_ground_floor_type_C1(valor):
    if ((valor == 'x') or (valor == 'v')):
        return 1;
    else: return 0;

def binario_ground_floor_type_C2(valor):
    if ((valor == 'z') or (valor == 'm')):
        return 1;
    else: return 0;
    

df['ground_floor_type_C0'] =0
df['ground_floor_type_C1'] =0
df['ground_floor_type_C2'] =0

df['ground_floor_type_C0'] = df['ground_floor_type'].apply(binario_ground_floor_type_C0)
df['ground_floor_type_C1'] = df['ground_floor_type'].apply(binario_ground_floor_type_C1)
df['ground_floor_type_C2'] = df['ground_floor_type'].apply(binario_ground_floor_type_C2)
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... roof_type_C1 roof_type_C0  \
# 0                      t               r  ...            0            1
# ...

# %%
df["other_floor_type"].value_counts()
# Out:
# q    165282
# x     43448
# j     39843
# s     12028
# Name: other_floor_type, dtype: int64

# %%
#other_floor_type
# valor s= 001
# valor j= 010
# valor x= 011
# valor q= 100

def binario_other_floor_type_C0(valor):
    if ((valor == 's') or (valor == 'x')):
        return 1;
    else: return 0;
    
def binario_other_floor_type_C1(valor):
    if ((valor == 'j') or (valor == 'x')):
        return 1;
    else: return 0;

def binario_other_floor_type_C2(valor):
    if ((valor == 'q')):
        return 1;
    else: return 0;
    

df['other_floor_type_C0'] =0
df['other_floor_type_C1'] =0
df['other_floor_type_C2'] =0

df['other_floor_type_C0'] = df['other_floor_type'].apply(binario_other_floor_type_C0)
df['other_floor_type_C1'] = df['other_floor_type'].apply(binario_other_floor_type_C1)
df['other_floor_type_C2'] = df['other_floor_type'].apply(binario_other_floor_type_C2)
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... land_surface_condition_C1  \
# 0                      t               r  ...                         0
# ...

# %%
df["position"].value_counts()
# Out:
# s    202090
# t     42896
# j     13282
# o      2333
# Name: position, dtype: int64

# %%
#position
# valor t= 001
# valor s= 010
# valor j= 011
# valor o= 100

def binario_position_C0(valor):
    if ((valor == 't') or (valor == 'j')):
        return 1;
    else: return 0;
    
def binario_position_C1(valor):
    if ((valor == 's') or (valor == 'j')):
        return 1;
    else: return 0;

def binario_position_C2(valor):
    if ((valor == 'o')):
        return 1;
    else: return 0;
    

df['position_C0'] =0
df['position_C1'] =0
df['position_C2'] =0

df['position_C0'] = df['position'].apply(binario_position_C0)
df['position_C1'] = df['position'].apply(binario_position_C1)
df['position_C2'] = df['position'].apply(binario_position_C2)
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... foundation_type_C2  \
# 0                      t               r  ...                  0
# 1                      o               r  ...                  0
# ...

# %%
df["plan_configuration"].value_counts()
# Out:
# d    250072
# q      5692
# u      3649
# s       346
# c       325
# a       252
# o       159
# m        46
# n        38
# f        22
# Name: plan_configuration, dtype: int64

# %%
#plan_configuration
# valor d= 0001
# valor q= 0010
# valor u= 0011
# valor s= 0100
# valor c= 0101
# valor a= 0110
# valor o= 0111
# valor m= 1000
# valor n= 1001
# valor f= 1010

def binario_plan_configuration_C0(valor):
    if ((valor == 'd') or (valor == 'u') or (valor == 'c') or (valor == 'o') or (valor == 'n')):
        return 1;
    else: return 0;
    
def binario_plan_configuration_C1(valor):
    if ((valor == 'q') or (valor == 'u') or (valor == 'a') or (valor == 'o') or (valor == 'f')):
        return 1;
    else: return 0;

def binario_plan_configuration_C2(valor):
    if ((valor == 's') or (valor == 'c') or (valor == 'a') or (valor == 'o')):
        return 1;
    else: return 0;
    
def binario_plan_configuration_C3(valor):
    if ((valor == 'm') or (valor == 'n') or (valor == 'f')):
        return 1;
    else: return 0;
    

df['plan_configuration_C0'] =0
df['plan_configuration_C1'] =0
df['plan_configuration_C2'] =0
df['plan_configuration_C3'] =0

df['plan_configuration_C0'] = df['plan_configuration'].apply(binario_plan_configuration_C0)
df['plan_configuration_C1'] = df['plan_configuration'].apply(binario_plan_configuration_C1)
df['plan_configuration_C2'] = df['plan_configuration'].apply(binario_plan_configuration_C2)
df['plan_configuration_C3'] = df['plan_configuration'].apply(binario_plan_configuration_C3)

df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... other_floor_type_C0  \
# 0                      t               r  ...                   0
# ...

# %%
df["legal_ownership_status"].value_counts()
# Out:
# v    250939
# a      5512
# w      2677
# r      1473
# Name: legal_ownership_status, dtype: int64

# %%
#legal_ownership_status
# valor v= 001
# valor a= 010
# valor w= 011
# valor r= 100

def binario_legal_ownership_status_C0(valor):
    if ((valor == 'v') or (valor == 'w')):
        return 1;
    else: return 0;
    
def binario_legal_ownership_status_C1(valor):
    if ((valor == 'a') or (valor == 'w')):
        return 1;
    else: return 0;

def binario_legal_ownership_status_C2(valor):
    if ((valor == 'r')):
        return 1;
    else: return 0;
    

df['legal_ownership_status_C0'] =0
df['legal_ownership_status_C1'] =0
df['legal_ownership_status_C2'] =0

df['legal_ownership_status_C0'] = df['legal_ownership_status'].apply(binario_legal_ownership_status_C0)
df['legal_ownership_status_C1'] = df['legal_ownership_status'].apply(binario_legal_ownership_status_C1)
df['legal_ownership_status_C2'] = df['legal_ownership_status'].apply(binario_legal_ownership_status_C2)
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#   land_surface_condition foundation_type  ... position_C0 position_C1  \
# 0                      t               r  ...           1           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260601 entries, 0 to 260600
# Data columns (total 63 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  int64
#  2   geo_level_2_id                          260601 non-null  int64
#  3   geo_level_3_id                          260601 non-null  int64
#  4   count_floors_pre_eq                     260601 non-null  int64
#  5   age                                     260601 non-null  int64
#  6   area_percentage                         260601 non-null  int64
#  7   height_percentage                       260601 non-null  int64
#  8   land_surface_condition                  260601 non-null  object
#  9   foundation_type                         260601 non-null  object
# ...

# %%
#land_surface_condition                 
#foundation_type                        
#roof_type                              
#ground_floor_type                      
#other_floor_type                       
#position                                
#plan_configuration                      
#legal_ownership_status                 
df = df.drop(['land_surface_condition', 'foundation_type', 'roof_type','ground_floor_type','other_floor_type',\
         'position','plan_configuration','legal_ownership_status'], axis=1)
df.head()
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
# 2        94947              21             363            8973
# 3       590882              22             418           10694
# 4       201944              11             131            1488
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
# 2                    2   10                5                  5
# 3                    2   10                6                  5
# 4                    3   30                8                  9
#
#    has_superstructure_adobe_mud  has_superstructure_mud_mortar_stone  ...  \
# 0                          True                                 True  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 260601 entries, 0 to 260600
# Data columns (total 55 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   building_id                             260601 non-null  int64
#  1   geo_level_1_id                          260601 non-null  int64
#  2   geo_level_2_id                          260601 non-null  int64
#  3   geo_level_3_id                          260601 non-null  int64
#  4   count_floors_pre_eq                     260601 non-null  int64
#  5   age                                     260601 non-null  int64
#  6   area_percentage                         260601 non-null  int64
#  7   height_percentage                       260601 non-null  int64
#  8   has_superstructure_adobe_mud            260601 non-null  bool
#  9   has_superstructure_mud_mortar_stone     260601 non-null  bool
# ...
